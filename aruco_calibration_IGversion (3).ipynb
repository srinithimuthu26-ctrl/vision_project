# %% [markdown]
# # Camera calibration using CHARUCO
#
# ## Libraries used
# We need to import the following libraries

# %%
import numpy as np       #Maths library
import cv2               #openCV
import PIL               #Library for Image file manipulation
import os                #To access files and folders
from cv2 import aruco    #ArUco main library
import math

# Library to Print nice graphs
#from mpl_toolkits.mplot3d import Axes3D
import matplotlib.pyplot as plt
import matplotlib as mpl
import pandas as pd
# %matplotlib nbagg

# %% [markdown]
# ### Create the CHARUCO chessboard
#
# First, we create the board in a folder called workdir. The result will be a tiffimage.

# %%
# Get the current folder
dirname = os.getcwd()

# Create a folder workdir if it does not exist and then change to the folder THESE NEED TO CHANGE FOR MAC OS
workdir = dirname+"\workdir"
try:
    os.mkdir(workdir)
except OSError:
    pass

os.chdir(workdir)

#Load the dictionary of ArUco for 6x6
aruco_dict = aruco.getPredefinedDictionary(aruco.DICT_6X6_250)

#Create the board, draw it, and save it in the folder
#board = aruco.CharucoBoard((7, 5), 1, .8, aruco_dict)
board = aruco.CharucoBoard((7, 5), 0.025, 0.020, aruco_dict)
imboard = board.generateImage((2000, 2000))
cv2.imwrite(workdir + "\chessboard.tiff", imboard)

#Create a figure with a subplot and plot it below for an inspection of the ChAruco board (we are using various settings)
fig = plt.figure()
ax = fig.add_subplot(1,1,1)
plt.imshow(imboard, cmap = mpl.cm.gray, interpolation = "nearest")
ax.axis("off")
plt.show()
# Out:
# <>:5: SyntaxWarning: invalid escape sequence '\w'
# <>:20: SyntaxWarning: invalid escape sequence '\c'
# <>:5: SyntaxWarning: invalid escape sequence '\w'
# <>:20: SyntaxWarning: invalid escape sequence '\c'
# C:\Users\Srinithi\AppData\Local\Temp\ipykernel_20372\2392336133.py:5: SyntaxWarning: invalid escape sequence '\w'
#   workdir = dirname+"\workdir"
# C:\Users\Srinithi\AppData\Local\Temp\ipykernel_20372\2392336133.py:20: SyntaxWarning: invalid escape sequence '\c'
#   cv2.imwrite(workdir + "\chessboard.tiff", imboard)
# <div id='8a10d754-8acd-4eb0-9566-8f3b283b7eb8'></div>

# %% [markdown]
# You need to <font color='red'>print</font> the board or use the ones provided by IG.
#
# Stick the board on a rigid surface, e.g. an A4 notepad, and <font color='red'>take photos</font> from multiple angles (>=20) with the camera you want to calibrate.
#
# Save them under a new \workdir\data folder.

# %% [markdown]
# ### Use the board to calibrate the camera
# The next piece of code will load all the images from the \data folder

# %%
datadir = workdir+"\data\\"
images = np.array([datadir + f for f in os.listdir(datadir) if f.endswith(".jpg") ])
order = np.argsort([int(p.split(".")[-2].split("_")[-1]) for p in images])
images = images[order]
images
# Out:
# <>:1: SyntaxWarning: invalid escape sequence '\d'
# <>:1: SyntaxWarning: invalid escape sequence '\d'
# C:\Users\Srinithi\AppData\Local\Temp\ipykernel_20372\1092032360.py:1: SyntaxWarning: invalid escape sequence '\d'
#   datadir = workdir+"\data\\"
# array(['c:\\Users\\Srinithi\\Desktop\\MECHATRONICS II\\vision_project\\workdir\\data\\calib_01.jpg',
#        'c:\\Users\\Srinithi\\Desktop\\MECHATRONICS II\\vision_project\\workdir\\data\\calib_02.jpg',
#        'c:\\Users\\Srinithi\\Desktop\\MECHATRONICS II\\vision_project\\workdir\\data\\calib_03.jpg',
#        'c:\\Users\\Srinithi\\Desktop\\MECHATRONICS II\\vision_project\\workdir\\data\\calib_04.jpg',
#        'c:\\Users\\Srinithi\\Desktop\\MECHATRONICS II\\vision_project\\workdir\\data\\calib_05.jpg',
#        'c:\\Users\\Srinithi\\Desktop\\MECHATRONICS II\\vision_project\\workdir\\data\\calib_06.jpg',
#        'c:\\Users\\Srinithi\\Desktop\\MECHATRONICS II\\vision_project\\workdir\\data\\calib_07.jpg',
#        'c:\\Users\\Srinithi\\Desktop\\MECHATRONICS II\\vision_project\\workdir\\data\\calib_08.jpg',
#        'c:\\Users\\Srinithi\\Desktop\\MECHATRONICS II\\vision_project\\workdir\\data\\calib_09.jpg',
#        'c:\\Users\\Srinithi\\Desktop\\MECHATRONICS II\\vision_project\\workdir\\data\\calib_10.jpg',
#        'c:\\Users\\Srinithi\\Desktop\\MECHATRONICS II\\vision_project\\workdir\\data\\calib_11.jpg',
#        'c:\\Users\\Srinithi\\Desktop\\MECHATRONICS II\\vision_project\\workdir\\data\\calib_12.jpg',
#        'c:\\Users\\Srinithi\\Desktop\\MECHATRONICS II\\vision_project\\workdir\\data\\calib_13.jpg'],
#       dtype='<U82')

# %% [markdown]
# We are going to print the images to see what you have got. Check that all images show the board

# %%
plotsize=round(math.sqrt(len(images)))+1
fig = plt.figure()
t=1
for an_im in images:
    im = PIL.Image.open(an_im)
    ax = fig.add_subplot(plotsize,plotsize,t)
    t+=1
    plt.imshow(im)
# Out:
# <div id='cd82bcfd-b4d5-435c-8567-2dc2ba24cd78'></div>

# %% [markdown]
# Zoom to the first image (index:0)

# %%
im = PIL.Image.open(images[0])
fig = plt.figure()
ax = fig.add_subplot(1,1,1)
plt.imshow(im)
#ax.axis('off')
plt.show()
# Out:
# <div id='f365e926-6e13-4d50-b5ed-0de21e0995de'></div>

# %% [markdown]
# Now, the camera calibration can be done using all the images of the chessboard. Two functions are necessary:
#
# * The first (read_chessboards) will detect markers on all the images and.
# * The second (calibrate_camera)will proces the detected markers to estimage the camera calibration data.

# %% [markdown]
# The code below is the definition of the function to read the chessboard

# %%
def read_chessboards(images):
    """
    Charuco base pose estimation.
    """
    print("POSE ESTIMATION STARTS:")
    allCorners = []
    allIds = []
    decimator = 0
    # SUB PIXEL CORNER DETECTION CRITERION
    criteria = (cv2.TERM_CRITERIA_EPS + cv2.TERM_CRITERIA_MAX_ITER, 100, 0.00001)

    for im in images:
        print("=> Processing image {0}".format(im))
        frame = cv2.imread(im)
        gray = cv2.cvtColor(frame, cv2.COLOR_BGR2GRAY)
        corners, ids, rejectedImgPoints = cv2.aruco.detectMarkers(gray, aruco_dict)
        
        if len(corners)>0:
            # SUB PIXEL DETECTION
            for corner in corners:
                cv2.cornerSubPix(gray, corner, 
                                 winSize = (3,3), 
                                 zeroZone = (-1,-1), 
                                 criteria = criteria)
            res2 = cv2.aruco.interpolateCornersCharuco(corners,ids,gray,board)        
            if res2[1] is not None and res2[2] is not None and len(res2[1])>3 and decimator%1==0:
                allCorners.append(res2[1])
                allIds.append(res2[2])              
        
        decimator+=1   

    imsize = gray.shape
    return allCorners,allIds,imsize

# %% [markdown]
# The line below calls the above function for all images and saves the results in allCorners, allIds

# %%
allCorners,allIds,imsize=read_chessboards(images)
# Out:
# POSE ESTIMATION STARTS:
# => Processing image c:\Users\Srinithi\Desktop\MECHATRONICS II\vision_project\workdir\data\calib_01.jpg
# => Processing image c:\Users\Srinithi\Desktop\MECHATRONICS II\vision_project\workdir\data\calib_02.jpg
# => Processing image c:\Users\Srinithi\Desktop\MECHATRONICS II\vision_project\workdir\data\calib_03.jpg
# => Processing image c:\Users\Srinithi\Desktop\MECHATRONICS II\vision_project\workdir\data\calib_04.jpg
# => Processing image c:\Users\Srinithi\Desktop\MECHATRONICS II\vision_project\workdir\data\calib_05.jpg
# => Processing image c:\Users\Srinithi\Desktop\MECHATRONICS II\vision_project\workdir\data\calib_06.jpg
# => Processing image c:\Users\Srinithi\Desktop\MECHATRONICS II\vision_project\workdir\data\calib_07.jpg
# => Processing image c:\Users\Srinithi\Desktop\MECHATRONICS II\vision_project\workdir\data\calib_08.jpg
# => Processing image c:\Users\Srinithi\Desktop\MECHATRONICS II\vision_project\workdir\data\calib_09.jpg
# => Processing image c:\Users\Srinithi\Desktop\MECHATRONICS II\vision_project\workdir\data\calib_10.jpg
# => Processing image c:\Users\Srinithi\Desktop\MECHATRONICS II\vision_project\workdir\data\calib_11.jpg
# => Processing image c:\Users\Srinithi\Desktop\MECHATRONICS II\vision_project\workdir\data\calib_12.jpg
# => Processing image c:\Users\Srinithi\Desktop\MECHATRONICS II\vision_project\workdir\data\calib_13.jpg

# %% [markdown]
# And this is the definition of the function that performs the calibration

# %%
def calibrate_camera(allCorners,allIds,imsize):   
    """
    Calibrates the camera using the dected corners.
    """
    print("CAMERA CALIBRATION")
    
    cameraMatrixInit = np.array([[ 1000.,    0., imsize[0]/2.],
                                 [    0., 1000., imsize[1]/2.],
                                 [    0.,    0.,           1.]])

    distCoeffsInit = np.zeros((5,1))
    flags = (cv2.CALIB_USE_INTRINSIC_GUESS + cv2.CALIB_RATIONAL_MODEL + cv2.CALIB_FIX_ASPECT_RATIO) 
    #flags = (cv2.CALIB_RATIONAL_MODEL) 
    (ret, camera_matrix, distortion_coefficients0, 
     rotation_vectors, translation_vectors,
     stdDeviationsIntrinsics, stdDeviationsExtrinsics, 
     perViewErrors) = cv2.aruco.calibrateCameraCharucoExtended(
                      charucoCorners=allCorners,
                      charucoIds=allIds,
                      board=board,
                      imageSize=imsize,
                      cameraMatrix=cameraMatrixInit,
                      distCoeffs=distCoeffsInit,
                      flags=flags,
                      criteria=(cv2.TERM_CRITERIA_EPS & cv2.TERM_CRITERIA_COUNT, 10000, 1e-9))

    return ret, camera_matrix, distortion_coefficients0, rotation_vectors, translation_vectors

# %% [markdown]
# Now we run the calibration function and get back a number of variables.
#
# ret: is the reprojection error obtained from the calibration (the smaller the better)
# CM : is the camera matrix to pass to the pose estimation
# dist_coef: is the distrortion coefficient matrix to pass to the pose estimation
# rvecs, tvecs: are the rotational and translational matrices of the ArUco markers the function used.
#
# (Note: By executing the function with %time in the begining we are going to get the duration this command will take)

# %%
# %time ret, CM, dist_coef, rvecs, tvecs = calibrate_camera(allCorners,allIds,imsize)
# Out:
# CAMERA CALIBRATION
# CPU times: total: 469 ms
# Wall time: 487 ms

# %%
ret
# Out:
# 0.5004737133919491

# %%
CM
# Out:
# array([[1.34509339e+03, 0.00000000e+00, 8.63344180e+02],
#        [0.00000000e+00, 1.34509339e+03, 6.28220527e+02],
#        [0.00000000e+00, 0.00000000e+00, 1.00000000e+00]])

# %%
dist_coef
# Out:
# array([[-0.03925357],
#        [-0.53917339],
#        [ 0.00856959],
#        [-0.01768928],
#        [ 1.25478213],
#        [-0.01667141],
#        [-0.0956405 ],
#        [ 0.07327404],
#        [ 0.        ],
#        [ 0.        ],
#        [ 0.        ],
#        [ 0.        ],
#        [ 0.        ],
#        [ 0.        ]])

# %% [markdown]
# ### Save the Camera Matrix and the distortion Coefficient using numpy
#
# This process will create a file named Callibration.npz that we can later use for the pose estimation.
# You might want to change the name to include an indication of the camera this information refers to.

# %%
with open('Calibration_v1.npz', 'wb') as f:
...     np.savez(f, CM=CM, dist_coef=dist_coef)

# %%
data = np.load('Calibration_v1.npz')
print("Files inside:", data.files)  # shows the variable names
print("Camera Matrix (CM):\n", data['CM'])
print("Distortion Coefficients (dist_coef):\n", data['dist_coef'])
# Out:
# Files inside: ['CM', 'dist_coef']
# Camera Matrix (CM):
#  [[1.34509339e+03 0.00000000e+00 8.63344180e+02]
#  [0.00000000e+00 1.34509339e+03 6.28220527e+02]
#  [0.00000000e+00 0.00000000e+00 1.00000000e+00]]
# Distortion Coefficients (dist_coef):
#  [[-0.03925357]
#  [-0.53917339]
#  [ 0.00856959]
#  [-0.01768928]
#  [ 1.25478213]
#  [-0.01667141]
#  [-0.0956405 ]
#  [ 0.07327404]
#  [ 0.        ]
#  [ 0.        ]
#  [ 0.        ]
#  [ 0.        ]
#  [ 0.        ]
#  [ 0.        ]]

# %% [markdown]
# ### Check calibration results

# %%
# %matplotlib inline
i=7 # select image id
plt.figure()
frame = cv2.imread(images[i])
img_undist = cv2.undistort(frame,CM,dist_coef,None)
frame_rgb = cv2.cvtColor(frame, cv2.COLOR_BGR2RGB)
img_undist_rgb = cv2.cvtColor(img_undist, cv2.COLOR_BGR2RGB)
plt.figure(figsize=(12, 6))
plt.subplot(1,2,1)
plt.imshow(frame)
plt.title("Raw image")
plt.axis("off")
plt.subplot(1,2,2)
plt.imshow(img_undist)
plt.title("Corrected image")
plt.axis("off")
plt.show()
